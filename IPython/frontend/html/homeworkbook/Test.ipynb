# %%
# %load_ext rmagicfrom IPython.core.displaypub import publish_display_datapublish_display_data('Assignment1', {'text/html':'<h2>Question 1</h2>'})
# Out:
# <h2>Question 1</h2>

# %%
# %%RX = rnorm(40)Y = rnorm(40)plot(X,Y, pch=24, bg='red', cex=2)print(summary(lm(Y~X)))
# Out:
# Call:lm(formula = Y ~ X)Residuals:     Min       1Q   Median       3Q      Max -1.79573 -0.33207 -0.00715  0.33519  2.51176 Coefficients:            Estimate Std. Error t value Pr(>|t|)(Intercept)   0.1661     0.1488   1.117    0.271X             0.1794     0.1555   1.154    0.256Residual standard error: 0.9405 on 38 degrees of freedomMultiple R-squared: 0.03385,	Adjusted R-squared: 0.008427 F-statistic: 1.331 on 1 and 38 DF,  p-value: 0.2558

# %%
publish_display_data('Assignment1', {'text/latex':r'What is the correlation, $\rho$?',                                     'text/html':'<h2>Answer</h2>'})
# Out:
# What is the correlation, $\rho$?
