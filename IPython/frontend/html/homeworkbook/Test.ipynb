# %%
# Out:
# <h2>Question 1</h2>

# %%
# Out:
# Call:lm(formula = Y ~ X)Residuals:    Min      1Q  Median      3Q     Max -1.8238 -0.6113  0.1537  0.6076  2.1266 Coefficients:            Estimate Std. Error t value Pr(>|t|)(Intercept)  0.20013    0.14226   1.407    0.168X           -0.03874    0.13943  -0.278    0.783Residual standard error: 0.8918 on 38 degrees of freedomMultiple R-squared: 0.002027,	Adjusted R-squared: -0.02424 F-statistic: 0.07719 on 1 and 38 DF,  p-value: 0.7826

# %%
# Out:
# What is the correlation, $\rho$?
# <h2>Answer</h2>
