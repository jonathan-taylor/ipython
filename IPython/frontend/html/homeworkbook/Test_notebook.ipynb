# %%
from IPython.core.displaypub import publish_display_data%load_ext rmagicpublish_display_data('Assignment1', {'text/html':'<h2>Question 1</h2>'})
# Out:
# <h2>Question 1</h2>

# %%
# %%R X = rnorm(40)Y = rnorm(40)plot(X,Y, pch=24, bg='red', cex=2)

# %%
publish_display_data('Assignment1',{'text/latex':r'''What is the correlation, $\rho$?  We could also have plotted with matplotlib...'''})
# Out:
# What is the correlation, $\rho$?  We could also have plotted with matplotlib...

# %%
import pylab%Rpull X Ypylab.scatter(X, Y, c='r')pylab.gca().set_xlabel('X')pylab.gca().set_ylabel('Y')

# %%
publish_display_data('Assignment1',{'text/html':r'''We might include some other html stuff, too. <iframe width="560" height="315" src="http://www.youtube.com/embed/sf49cw0134U" frameborder="0" allowfullscreen></iframe>'''})
# Out:
# We might include some other html stuff, too. <iframe width="560" height="315" src="http://www.youtube.com/embed/sf49cw0134U" frameborder="0" allowfullscreen></iframe>

# %%
publish_display_data('Assignment1',{'text/html':'<h2>Answer</h2>'})
# Out:
# <h2>Answer</h2>

# %%
publish_display_data('Assignment', {'text/html': '''<input type="radio" name="group1" value="Milk"> Milk<br><input type="radio" name="group1" value="Butter" checked> Butter<br>'''})
# Out:
# <input type="radio" name="group1" value="Milk"> Milk<br><input type="radio" name="group1" value="Butter" checked> Butter<br>

# %% [markdown]
# ## Magics

# %%
run magics/homework.py

# %%
# %%MultipleChoiceSetup 1X = rnorm(200)Y = rnorm(200)plot(X,Y)
# Out:
# <h2>Question 1</h2>

# %%
# %%MultipleChoiceQuestion 1question_text = 'Is the correlation:'choices = ['positive', 'negative', 'zero']
# Out:
# Is the correlation:
#         <input type="radio" name="2917924107d1f41e90632af0a98a4793" value="zero"> zero<br>                <input type="radio" name="2917924107d1f41e90632af0a98a4793" value="negative"> negative<br>                <input type="radio" name="2917924107d1f41e90632af0a98a4793" value="positive"> positive<br>

# %%
# %%MultipleChoiceSetup 2X = rnorm(20)Y = rnorm(20) + Xprint(summary(lm(Y~X)))true_corr = cor(X,Y)
# Out:
# <h2>Question 2</h2>
# Call:lm(formula = Y ~ X)Residuals:     Min       1Q   Median       3Q      Max -1.22516 -0.51580 -0.04977  0.60190  1.59082 Coefficients:            Estimate Std. Error t value Pr(>|t|)    (Intercept)   0.1294     0.1761   0.735    0.472    X             0.9515     0.1867   5.097 7.53e-05 ***---Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1 Residual standard error: 0.7875 on 18 degrees of freedomMultiple R-squared: 0.5907,	Adjusted R-squared: 0.568 F-statistic: 25.98 on 1 and 18 DF,  p-value: 7.533e-05

# %%
true_corr = %R cor(X,Y)

# %%
# %%MultipleChoiceQuestion 2question_text = r'Up to 1 significant digit, what is the correlation between $X$ and $Y$?'while True:    choices = ['%0.1f' % c for c in list(np.random.random(size=(3,))*2-1) + [true_corr]]    if len(set(choices)) == 4 :        break
# Out:
# Up to 1 significant digit, what is the correlation between $X$ and $Y$?
#         <input type="radio" name="96eedd18fc3bbd5cef5164686e0dce1a" value="0.0"> 0.0<br>                <input type="radio" name="96eedd18fc3bbd5cef5164686e0dce1a" value="-0.9"> -0.9<br>                <input type="radio" name="96eedd18fc3bbd5cef5164686e0dce1a" value="0.8"> 0.8<br>                <input type="radio" name="96eedd18fc3bbd5cef5164686e0dce1a" value="0.2"> 0.2<br>
